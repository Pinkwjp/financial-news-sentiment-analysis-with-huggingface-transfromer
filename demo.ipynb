# %%
from src.utils import create_classifier_pipeline

classifier = create_classifier_pipeline()

# %%
from src.utils import fetch_company_news


company_name = 'Tesla Inc'

news_df = fetch_company_news(company_name)

print(f'collected {news_df.size} news about {company_name}.')
# Out:
# collected 900 news about Tesla Inc.

# %%
sentiments = classifier(news_df['title'].to_list())

# %%
import pandas as pd 


news_and_sentiments_df = pd.concat([news_df, pd.DataFrame(sentiments)], axis=1)

news_and_sentiments_df.head(2)
# Out:
#                                                                         title  \
# 0  Friday's Top 5 Trending Stocks: What's The Scoop On GameStop, SoFi, Tesla?
# 1              Tesla shares roar back to trillion-dollar value on Trump’s win
#
#    desc        date                   datetime  \
# 0  None  2 days ago 2024-11-08 20:54:17.398977
# 1  None   Yesterday 2024-11-09 20:54:17.399372
#
#                                                                                                                                                                                                                                                                                                                                   link  \
# 0  https://news.google.?hl=en-CA&gl=CA&ceid=CA%3Aen
# 1                                                  https://news.google.com/read/CBMingFBVV95cUxPSllYODdmMExRRjBVRWoyNmdaQWhQdVJfbHZnb1VldXNVT3h5MWJORFNFTHJKUUxsVEQtVi1hRDROTEVrTXc2LThXSVh3Z282dVM2azh6bnlMZjEtY215cHJTRXpKNFFtajY1SEtOR3Z5SjNKS3lZS3Jqdm5fVVZNdTRxUXZzbmJ2ZkJIa0lEcm9EUzFUX3pZaFZacGNYQQ?hl=en-CA&gl=CA&ceid=CA%3Aen
#
#                                                                                                                        img  \
# 0                                                                                                                     None
# 1  https://news.google.com/api/attachments/CC8iK0NnNWxkbkpGTUU1bVRtZDVYM0o1VFJDM0FSaVRBaWdCTWdhQlZZck9uUWs=-w200-h112-p-df
#
#       media  site           reporter     label     score
# 0  Benzinga  None  By Erica Kollmann   neutral  0.999827
# 1   Fortune  None        By Esha Dey  positive  0.999527

# %%
titles_and_sentiments_df = news_and_sentiments_df[['title', 'label', 'score']]
titles_and_sentiments_df.head()
# Out:
#                                                                                 title  \
# 0          Friday's Top 5 Trending Stocks: What's The Scoop On GameStop, SoFi, Tesla?
# 1                      Tesla shares roar back to trillion-dollar value on Trump’s win
# 2                           Hedge Funds Shorting Tesla Just Lost More Than $5 Billion
# 3  Tesla, Inc. (TSLA)’s Bold Bet on Robotaxis: The Next Big Thing in Robotics Stocks?
# 4     Will retail investors rekindle their love for Tesla? It could depend on Nvidia.
#
#       label     score
# 0   neutral  0.999827
# 1  positive  0.999527
# 2  negative  0.997982
# 3   neutral  0.999113
# 4  positive  0.980796

# %%
negative_news = titles_and_sentiments_df[
                    titles_and_sentiments_df['label'] == 'negative'
                        ].sort_values('score', ascending=False)

positive_news = titles_and_sentiments_df[
                    titles_and_sentiments_df['label'] == 'positive'
                        ].sort_values('score', ascending=False)

# %%
negative_news.head(10)
# Out:
#                                                                                                      title  \
# 26                                 Tesla shares fall after Elon Musk’s glitzy ‘Cybercab’ event disappoints
# 28                                               Hedge funds shorting Tesla just lost more than $5 billion
# 77  Tesla Shares Slide In Pre-Market As Sales Of Elon Musk-Led Company's Made-In-China EVs Drop In October
# 2                                                Hedge Funds Shorting Tesla Just Lost More Than $5 Billion
# 53                                               Hedge Funds Shorting Tesla Just Lost More Than $5 Billion
# 38                                        Sigma Planning Corp Decreases Stake in Tesla, Inc. (NASDAQ:TSLA)
# 67                                       Tesla investors lose bid for new US trial over Musk's 2018 tweets
# 29                               Carr Financial Group Corp Decreases Position in Tesla, Inc. (NASDAQ:TSLA)
# 19                                      Tesla's China Sales Plunge to 6-Month Low In October, Exports Rise
# 79                     Tesla, Inc. (NASDAQ:TSLA) Stock Holdings Decreased by ARK Investment Management LLC
#
#        label     score
# 26  negative  0.998511
# 28  negative  0.998511
# 77  negative  0.998159
# 2   negative  0.997982
# 53  negative  0.997982
# 38  negative  0.997051
# 67  negative  0.996797
# 29  negative  0.995970
# 19  negative  0.994342
# 79  negative  0.991383

# %%
positive_news.head(10)
# Out:
#                                                                                                   title  \
# 25   Tesla shares soar more than 14% as Trump win is seen boosting Elon Musk's electric vehicle company
# 99   Tesla shares soar as Elon Musk's backing of Trump is seen reaping rewards for Texas-based EV maker
# 71               Tesla shares soar 14% as Trump win sets stage for Elon Musk's electric vehicle company
# 56                                                 Tesla Inc. stock rises Wednesday, outperforms market
# 49                                                  Tesla Inc. stock rises Thursday, outperforms market
# 94                                                  Tesla Inc. stock rises Thursday, outperforms market
# 74                       Trump victory fires financial markets sharply higher; EV maker Tesla jumps 15%
# 14  Elon Musk’s net worth rockets to over $300 billion as Trump win fuels optimism for Tesla and SpaceX
# 82                                               Why Tesla Stock Can Ride Even Higher After Q3 Earnings
# 1                                        Tesla shares roar back to trillion-dollar value on Trump’s win
#
#        label     score
# 25  positive  0.999689
# 99  positive  0.999666
# 71  positive  0.999640
# 56  positive  0.999636
# 49  positive  0.999631
# 94  positive  0.999631
# 74  positive  0.999623
# 14  positive  0.999579
# 82  positive  0.999552
# 1   positive  0.999527
