# %%
from src.utils import create_classifier_pipeline

classifier = create_classifier_pipeline()

# %%
from src.utils import fetch_company_news


company_name = 'Microsoft'

news_df = fetch_company_news(company_name)

print(f'collected {news_df.size} news about {company_name}.')
# Out:
# collected 918 news about Microsoft.

# %%
sentiments = classifier(news_df['title'].to_list())

# %%
import pandas as pd 


news_and_sentiments_df = pd.concat([news_df, pd.DataFrame(sentiments)], axis=1)

news_and_sentiments_df.head(2)
# Out:
#                                                title  desc        date  \
# 0  Microsoft added AI to software it has barely t...  None  2 days ago
# 1  Microsoft Reveals New Upgrade Warning For 850 ...  None  2 days ago
#
#                     datetime  \
# 0 2024-11-08 20:33:25.415322
# 1 2024-11-08 20:33:25.416322
#
#                                                 link  \
# 0  https://news.google.com/read/CBMilAFBVV95cUxOb...
# 1  https://news.google.com/read/CBMivwFBVV95cUxNU...
#
#                                                  img   media  site  \
# 0  https://news.google.com/api/attachments/CC8iK0...     CNN  None
# 1  https://news.google.com/api/attachments/CC8iL0...  Forbes  None
#
#            reporter     label     score
# 0  By John Towfighi  positive  0.883083
# 1    By Zak Doffman  negative  0.777851

# %%
titles_and_sentiments_df = news_and_sentiments_df[['title', 'label', 'score']]
titles_and_sentiments_df.head()
# Out:
#                                                                                              title  \
# 0     Microsoft added AI to software it has barely touched since 1985. The results are astonishing
# 1                              Microsoft Reveals New Upgrade Warning For 850 Million Windows Users
# 2                                   Microsoft says recent Windows 11 updates break SSH connections
# 3  Microsoft says Windows Mail app won’t fully disappear, but here is why you won’t want to use it
# 4                                     Better Artificial Intelligence Stock: Palantir vs. Microsoft
#
#       label     score
# 0  positive  0.883083
# 1  negative  0.777851
# 2  negative  0.539492
# 3   neutral  0.997093
# 4   neutral  0.976887

# %%
negative_news = titles_and_sentiments_df[
                    titles_and_sentiments_df['label'] == 'negative'
                        ].sort_values('score', ascending=False)

positive_news = titles_and_sentiments_df[
                    titles_and_sentiments_df['label'] == 'positive'
                        ].sort_values('score', ascending=False)

# %%
negative_news.head(10)
# Out:
#                                                                                   title  \
# 35                          1 Warning Sign That Could Send Microsoft Stock Down Further
# 45                    Xbox snags a PlayStation exclusive and Mac mini puts PCs to shame
# 32  Microsoft Has Large Unusual Call Options Activity - Investors Bullish On MSFT Stock
# 99    Microsoft risks shareholder lawsuit if it ignores Bitcoin and prices rise — NCPPR
# 71           Microsoft, Amazon Stocks Dumped by AI Robot Trader. Here's What It Bought.
# 6                   Microsoft (MSFT): Why Concerns Over Heavy AI Spending Are Overblown
# 10                      Microsoft investigates OneDrive issue causing macOS app freezes
# 66                    Microsoft’s decision on Bitcoin could trigger shareholder lawsuit
# 39                         Microsoft Update Warning—400 Million Windows PCs Now At Risk
# 46        Office and Microsoft 365 will soon cost more, and it's all Copilot AI's fault
#
#        label     score
# 35  negative  0.997421
# 45  negative  0.997160
# 32  negative  0.996877
# 99  negative  0.995583
# 71  negative  0.991733
# 6   negative  0.986682
# 10  negative  0.980489
# 66  negative  0.954477
# 39  negative  0.945432
# 46  negative  0.780452

# %%
positive_news.head(10)
# Out:
#                                                                                                                                     title  \
# 51                           Windows Server 2025 now generally available, with advanced security, improved performance, and cloud agility
# 42                                            Microsoft launches GenAI Accelerator with NVIDIA and GitHub to boost AI start-ups in the UK
# 95                           From static prediction to dynamic characterization: AI2BMD advances protein dynamics with ab initio accuracy
# 80                                                      Microsoft has reached $1M giveaway levels of desperation to attract users to Bing
# 55                                                              Microsoft Shows Room To Climb As Tesla, Nvidia, Amazon Near 52-Week Highs
# 88                                                              Microsoft Shows Room To Climb As Tesla, Nvidia, Amazon Near 52-Week Highs
# 70                                                   Jim Cramer Says Microsoft (MSFT) Will Have ‘Total Dominance’ in AI Enterprise Market
# 101                                                                            5 reasons Microsoft 365 is better than iWork for Mac users
# 77   Microsoft Corporation (MSFT) AI Chief Predicts 2025 Breakthrough in Persistent Memory, Paving Way for Transformative AI Interactions
# 11                                                 Palantir Stock vs. Microsoft Stock: Wall Street Says Only 1 Will Head Higher From Here
#
#         label     score
# 51   positive  0.999490
# 42   positive  0.999335
# 95   positive  0.999135
# 80   positive  0.998973
# 55   positive  0.998873
# 88   positive  0.998873
# 70   positive  0.998866
# 101  positive  0.998393
# 77   positive  0.998202
# 11   positive  0.992391
